# %% [markdown]
# ## Настройка

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Далее проводим манипуляции в ноутбуках `redis`, `redis-cluster`.

# %% [markdown]
# #### В итоге видим, что время в случае redis-cluster в среднем увеличилось почти в 2 раза. Это связано с тем, что нужно время на распределение по разным узлам.
